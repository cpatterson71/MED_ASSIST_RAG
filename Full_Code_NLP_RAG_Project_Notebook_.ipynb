# %% [markdown]
# <a href="https://colab.research.google.com/github/cpatterson71/MED_ASSIST_RAG/blob/main/Full_Code_NLP_RAG_Project_Notebook_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Business Context

# %% [markdown]
# The healthcare industry is rapidly evolving, with professionals facing increasing challenges in managing vast volumes of medical data while delivering accurate and timely diagnoses. The need for quick access to comprehensive, reliable, and up-to-date medical knowledge is critical for improving patient outcomes and ensuring informed decision-making in a fast-paced environment.
#
# Healthcare professionals often encounter information overload, struggling to sift through extensive research and data to create accurate diagnoses and treatment plans. This challenge is amplified by the need for efficiency, particularly in emergencies, where time-sensitive decisions are vital. Furthermore, access to trusted, current medical information from renowned manuals and research papers is essential for maintaining high standards of care.
#
# To address these challenges, healthcare centers can focus on integrating systems that streamline access to medical knowledge, provide tools to support quick decision-making, and enhance efficiency. Leveraging centralized knowledge platforms and ensuring healthcare providers have continuous access to reliable resources can significantly improve patient care and operational effectiveness.

# %% [markdown]
# **Common Questions to Answer**
#
# **1. Diagnostic Assistance**: "What are the common symptoms and treatments for pulmonary embolism?"
#
# **2. Drug Information**: "Can you provide the trade names of medications used for treating hypertension?"
#
# **3. Treatment Plans**: "What are the first-line options and alternatives for managing rheumatoid arthritis?"
#
# **4. Specialty Knowledge**: "What are the diagnostic steps for suspected endocrine disorders?"
#
# **5. Critical Care Protocols**: "What is the protocol for managing sepsis in a critical care unit?"

# %% [markdown]
# ### Objective

# %% [markdown]
# As an AI specialist, your task is to develop a RAG-based AI solution using renowned medical manuals to address healthcare challenges. The objective is to **understand** issues like information overload, **apply** AI techniques to streamline decision-making, **analyze** its impact on diagnostics and patient outcomes, **evaluate** its potential to standardize care practices, and **create** a functional prototype demonstrating its feasibility and effectiveness.

# %% [markdown]
# ### Data Description

# %% [markdown]
# The **Merck Manuals** are medical references published by the American pharmaceutical company Merck & Co., that cover a wide range of medical topics, including disorders, tests, diagnoses, and drugs. The manuals have been published since 1899, when Merck & Co. was still a subsidiary of the German company Merck.
#
# The manual is provided as a PDF with over 4,000 pages divided into 23 sections.

# %% [markdown]
# ## Installing and Importing Necessary Libraries and Dependencies

# %%
# Installation for GPU llama-cpp-python
# uncomment and run the following code in case GPU is being used
# !CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install llama-cpp-python==0.2.28 --force-reinstall --no-cache-dir -q

# Installation for CPU llama-cpp-python
# uncomment and run the following code in case GPU is not being used
# !CMAKE_ARGS="-DLLAMA_CUBLAS=off" FORCE_CMAKE=1 pip install llama-cpp-python==0.2.28 --force-reinstall --no-cache-dir -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 70.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 225.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 262.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 247.1 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × Building wheel for llama-cpp-python (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for llama-cpp-python
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (llama-cpp-python)

# %% [markdown]
# **Note**:
# - After running the above cell, kindly restart the runtime (for Google Colab) or notebook kernel (for Jupyter Notebook), and run all cells sequentially from the next cell.
# - On executing the above line of code, you might see a warning regarding package dependencies. This error message can be ignored as the above code ensures that all necessary libraries and their dependencies are maintained to successfully execute the code in ***this notebook***.

# %%
# For installing the libraries & downloading models from HF Hub
# !pip install huggingface_hub==0.35.3 pandas==2.2.2 tiktoken==0.12.0 pymupdf==1.26.5 langchain==0.3.27 langchain-community==0.3.31 chromadb==1.1.1 sentence-transformers==5.1.1 numpy==2.3.3 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.3/564.3 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 35.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 73.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 47.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 68.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 96.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.6/486.6 kB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 83.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 22.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Note**:
# - After running the above cell, kindly restart the runtime (for Google Colab) or notebook kernel (for Jupyter Notebook), and run all cells sequentially from the next cell.
# - On executing the above line of code, you might see a warning regarding package dependencies. This error message can be ignored as the above code ensures that all necessary libraries and their dependencies are maintained to successfully execute the code in ***this notebook***.

# %%
# !pip install langchain==0.1.20 langchain-community==0.0.38 numpy<2.0,>=1.22.4 -q
# Out:
# /bin/bash: line 1: 2.0,: No such file or directory

# %%
*(Redundant installation cell removed)*
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 69.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 8.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 457.6 kB/s eta 0:00:00
# ...

# %%
#Libraries for processing dataframes,text
import json,os
import tiktoken
import pandas as pd
import langchain.text_splitter

#Libraries for Loading Data, Chunking, Embedding, and Vector Databases
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.embeddings.sentence_transformer import SentenceTransformerEmbeddings
from langchain_community.vectorstores import Chroma

#Libraries for downloading and loading the llm
from huggingface_hub import hf_hub_download
from llama_cpp import Llama

# %% [markdown]
# ## Question Answering using LLM

# %% [markdown]
# #### Downloading and Loading the model

# %%
# Download model from Hugging Face Hub
model_path = hf_hub_download(
    repo_id="TheBloke/Mistral-7B-Instruct-v0.2-GGUF",
    filename="mistral-7b-instruct-v0.2.Q4_K_M.gguf"
)

# Load the model using llama_cpp
llm = Llama(
    model_path=model_path,
    n_ctx=2048,
    n_gpu_layers=-1  # Offloads all layers to the GPU
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# mistral-7b-instruct-v0.2.Q4_K_M.gguf:   0%|          | 0.00/4.37G [00:00<?, ?B/s]
# AVX = 1 | AVX_VNNI = 0 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 0 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |

# %% [markdown]
# #### Response

# %%
def response(query,max_tokens=128,temperature=0,top_p=0.95,top_k=50):
    model_output = llm(
      prompt=query,
      max_tokens=max_tokens,
      temperature=temperature,
      top_p=top_p,
      top_k=top_k
    )

    return model_output['choices'][0]['text']

# %% [markdown]
# ### Query 1: What is the protocol for managing sepsis in a critical care unit?

# %%
# Query 1
query = "What is the protocol for managing sepsis in a critical care unit?"
answer = response(query)
print(answer)
# Out:
# Sepsis is a life-threatening condition that can arise from an infection, and prompt recognition and appropriate management are crucial for improving outcomes. In a critical care unit, the following steps should be taken for managing sepsis:
#
# 1. Early recognition: Identify patients at risk of developing sepsis based on clinical signs, laboratory values, and medical history. Use validated scoring systems such as Sequential Organ Failure Assessment (SOFA) or Quick Sequential Organ Failure Assessment (qSOFA) to help identify suspected sepsis cases.
# 2. Immediate resuscitation

# %% [markdown]
# ### Query 2: What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?

# %%
# Query 2
query = "What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?"
answer = response(query)
print(answer)
# Out:
# Llama.generate: prefix-match hit
# Appendicitis is a medical condition characterized by inflammation of the appendix, a small tube-shaped organ located in the lower right side of the abdomen. The symptoms of appendicitis can vary from person to person, but some common signs include:
#
# 1. Abdominal pain: The pain is typically located in the lower right quadrant of the abdomen and may start as a mild discomfort that gradually worsens over time. It may be constant or come and go, and it can be accompanied by cramping or bloating.
# 2. Loss of appetite: People with

# %% [markdown]
# ### Query 3: What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?

# %%
# Load the model with an expanded context window
llm = Llama(
    model_path=model_path,
    n_ctx=4096,         # <--- Increase from 2048 to 4096 (or 8192)
    n_gpu_layers=-1
)
# Out:
# AVX = 1 | AVX_VNNI = 0 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 0 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |

# %%
# Query 3
query = "What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?"
answer = response(query, max_tokens=512)  # Increased max_tokens
print(answer)
# Out:
# Sudden patchy hair loss, also known as alopecia areata, is a common autoimmune disorder that affects both men and women. It is characterized by round or oval bald patches on the scalp, but it can also occur on other parts of the body such as the beard area, eyebrows, or eyelashes.
#
# The exact cause of alopecia areata is not known, but it is believed to be related to an abnormal immune response that attacks the hair follicles. Some possible triggers for this condition include stress, genetics, viral infections, and certain medications.
#
# There are several treatments for alopecia areata, and the most effective one depends on the severity and location of the bald patches. Here are some common treatment options:
#
# ...

# %% [markdown]
# ### Query 4:  What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?

# %%
# Query 4
query = "What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?"
answer = response(query, max_tokens=512)
print(answer)
# Out:
# Llama.generate: prefix-match hit
# A person who has sustained a physical injury to the brain tissue may require various treatments depending on the severity and location of the injury. Here are some common treatments recommended for brain injuries:
#
# 1. Emergency care: In case of a traumatic brain injury (TBI), it is essential to seek immediate medical attention. The primary goal in the initial phase is to ensure the person's safety, prevent further damage, and stabilize their condition. This may involve administering oxygen, controlling bleeding, managing pressure within the skull, and monitoring vital signs.
#
# 2. Rehabilitation: Rehabilitation is an essential component of treatment for brain injuries. It aims to help individuals regain lost skills and functions, improve overall quality of life, and prevent complications. Rehabilitation may include physical therapy, occupational therapy, speech-language therapy, cognitive rehabilitation, and social support services.
#
# ...

# %% [markdown]
# ### Query 5: What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?

# %%
# Query 5
query = "What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?"
answer = response(query, max_tokens=512)
print(answer)
# Out:
# Llama.generate: prefix-match hit
# First and foremost, it is essential to ensure the safety of the injured person. If possible, try to keep them calm and still to prevent further injury or discomfort. If the fracture is open (compound), take extra precautions to prevent infection by covering the wound with a clean dressing.
#
# Next, assess the severity of the fracture and determine if medical attention is required. If the person can walk with assistance or if the fracture is not displaced (meaning the bone ends are still aligned), they may be able to hike out with help. However, if the fracture is severe, displaced, or open, it is crucial to seek medical attention as soon as possible.
#
# If medical attention is not immediately available, follow these steps for temporary care and stabilization:
#
# 1. Immobilize the leg: Use a splint, sling, or other available materials to immobilize the leg above and below the fracture site. This will help prevent further injury and discomfort.
# ...

# %% [markdown]
# ## Question Answering using LLM with Prompt Engineering

# %% [markdown]
# ### Query 1: What is the protocol for managing sepsis in a critical care unit?

# %%
# Query 1
query = "What is the protocol for managing sepsis in a critical care unit?"
answer = response(query, max_tokens=512)
print(answer)
# Out:
# Llama.generate: prefix-match hit
# Sepsis is a life-threatening condition that can arise from an infection, and prompt recognition and appropriate management are crucial for improving outcomes. In a critical care unit, the following steps should be taken for managing sepsis:
#
# 1. Early recognition: Identify patients at risk of developing sepsis based on clinical signs, laboratory values, and medical history. Use validated scoring systems such as Sequential Organ Failure Assessment (SOFA) or Quick Sequential Organ Failure Assessment (qSOFA) to help identify suspected sepsis.
# 2. Immediate resuscitation: Begin fluid resuscitation with isotonic crystalloids to maintain adequate tissue perfusion and organ function. Monitor hemodynamic parameters such as mean arterial pressure, central venous pressure, and urine output. Consider the use of vasopressors or inotropes if necessary to maintain adequate blood pressure and organ perfusion.
# ...

# %% [markdown]
# ### Query 2: What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?

# %%
# Query 2
query = "What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?"
answer = response(query, max_tokens=512)
print(answer)
# Out:
# Llama.generate: prefix-match hit
# Appendicitis is a medical condition characterized by inflammation of the appendix, a small tube-shaped organ located in the lower right side of the abdomen. The symptoms of appendicitis can vary from person to person, but some common signs include:
#
# 1. Abdominal pain: The pain may start as a mild discomfort in the lower right side of the abdomen and gradually worsen over time. It is often described as a dull ache that becomes sharp and localized.
# 2. Loss of appetite: People with appendicitis may lose their appetite due to abdominal pain or nausea.
# 3. Nausea and vomiting: Vomiting is a common symptom of appendicitis, especially if the inflammation is severe.
# 4. Fever: A fever above 101°F (38.3°C) may be present in some cases.
# 5. Constipation or diarrhea: Both constipation and diarrhea can occur with appendicitis, depending on the location of the inflammation and the pressure it puts on the intestines.
# ...

# %% [markdown]
# ### Query 3: What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?

# %%
# Query 3
query = "What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?"
answer = response(query, max_tokens=512)
print(answer)
# Out:
# Llama.generate: prefix-match hit
# Sudden patchy hair loss, also known as alopecia areata, is a common autoimmune disorder that affects the hair follicles. It can cause round or oval bald patches on the scalp, beard, or other areas of the body where hair grows. The exact cause of alopecia areata is not known, but it's believed to be related to an abnormal immune response that attacks the hair follicles.
#
# There are several treatments and solutions for addressing sudden patchy hair loss:
#
# 1. Corticosteroids: These medications can help reduce inflammation and suppress the immune system, allowing the hair to grow back. They can be applied topically or taken orally.
# 2. Immunotherapy: This involves using drugs that alter the immune response to promote hair growth. One such drug is minoxidil, which has been shown to be effective in some cases of alopecia areata.
# ...

# %% [markdown]
# ### Query 4:  What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?

# %%
# Query 4
query = "What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?"
answer = response(query, max_tokens=512)
print(answer)
# Out:
# Llama.generate: prefix-match hit
# A person who has sustained a physical injury to the brain tissue may require various treatments depending on the severity and location of the injury. Here are some common treatments that may be recommended:
#
# 1. Emergency care: In case of a traumatic brain injury (TBI), it is essential to seek immediate medical attention. The primary goal of emergency care is to prevent further damage, stabilize the patient's condition, and ensure adequate oxygen supply to the brain.
# 2. Medications: Depending on the symptoms, healthcare professionals may prescribe medications to manage conditions such as seizures, pain, swelling, or infections. For instance, anti-inflammatory drugs, anticonvulsants, or steroids might be used.
# ...

# %% [markdown]
# ### Query 5: What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?

# %%
# Query 5
query = "What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?"
answer = response(query, max_tokens=512)
print(answer)
# Out:
# Llama.generate: prefix-match hit
# First and foremost, it is essential to ensure the safety of the injured person. If possible, try to keep them calm and still to prevent further injury or discomfort. If the fracture is open (compound), take extra precautions to prevent infection by covering the wound with a clean dressing.
#
# Next, assess the severity of the fracture and determine if medical attention is required. If the person can walk with assistance or if the fracture is not displaced (meaning the bone ends are still aligned), they may be able to hike out with help. However, if the fracture is severe, displaced, or open, it is crucial to seek medical attention as soon as possible.
#
# If medical attention is not immediately available, follow these steps for temporary care and stabilization:
#
# 1. Immobilize the leg: Use a splint, sling, or other available materials to immobilize the leg above and below the fracture site. This will help prevent further injury and discomfort.
# ...

# %% [markdown]
# ## Data Preparation for RAG

# %% [markdown]
# ### Loading the Data

# %%
# !pip install pymupdf -q

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from langchain_community.document_loaders import PyMuPDFLoader

# Candidate paths where the PDF might be located
possible_paths = [
    "/content/drive/MyDrive/med_dx/medical_diagnosis_manual.pdf",
    "/content/drive/MyDrive/medical_diagnosis_manual.pdf",
    "/content/medical_diagnosis_manual.pdf",
    "medical_diagnosis_manual.pdf"
]

pdf_filename = None
for path in possible_paths:
    if os.path.exists(path):
        pdf_filename = path
        break

if pdf_filename:
    loader = PyMuPDFLoader(pdf_filename)
    docs = loader.load()
    print(f"Successfully loaded {len(docs)} pages from '{pdf_filename}'.")
else:
    raise FileNotFoundError(
        "Could not locate 'medical_diagnosis_manual.pdf'. "
        "Please ensure the PDF is uploaded to your Google Drive or Colab file sidebar."
    )
# Out:
# Successfully loaded 4114 pages from '/content/drive/MyDrive/med_dx/medical_diagnosis_manual.pdf'.

# %%
# Load the Merck Manual PDF document
# Load the Merck Manual PDF document using the full path verified in cell [25]
loader = PyMuPDFLoader("/content/drive/MyDrive/med_dx/medical_diagnosis_manual.pdf")
docs = loader.load()

# %% [markdown]
# ### Data Overview

# %% [markdown]
# #### Checking the first 5 pages

# %%
# Check the metadata and content of the first 5 pages
for i, doc in enumerate(docs[:5]):
    print(f"--- Page {i + 1} ---")
    print(f"Metadata: {doc.metadata}")
    print(f"Content Preview:\n{doc.page_content[:300]}...\n")
# Out:
# --- Page 1 ---
# Metadata: {'source': '/content/drive/MyDrive/med_dx/medical_diagnosis_manual.pdf', 'file_path': '/content/drive/MyDrive/med_dx/medical_diagnosis_manual.pdf', 'page': 0, 'total_pages': 4114, 'format': 'PDF 1.7', 'title': 'The Merck Manual of Diagnosis & Therapy, 19th Edition', 'author': '', 'subject': '', 'keywords': '', 'creator': 'Atop CHM to PDF Converter', 'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationDate': 'D:20120615054440Z', 'modDate': 'D:20260722211534Z', 'trapped': ''}
# Content Preview:
# carl.pattersonsd@gmail.com
# 3Q1YKR8FGC
# This file is meant for personal use by carl.pattersonsd@gmail.com only.
# Sharing or publishing the contents in part or full is liable for legal action.
# ...
#
# --- Page 2 ---
# ...

# %% [markdown]
# #### Checking the number of pages

# %%
# Check the total number of pages loaded
print(f"Total number of pages: {len(docs)}")
# Out:
# Total number of pages: 4114

# %% [markdown]
# ### Data Chunking

# %%
# Initialize RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    length_function=len
)

# Split the loaded document pages into smaller text chunks
doc_chunks = text_splitter.split_documents(docs)

# Verify the output
print(f"Total number of chunks generated: {len(doc_chunks)}")
# Out:
# Total number of chunks generated: 18071

# %% [markdown]
# ### Embedding

# %%
# Initialize the Sentence Transformer embedding model
embedding_model = SentenceTransformerEmbeddings(
    model_name="all-MiniLM-L6-v2"
)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# ...

# %% [markdown]
# ### Vector Database

# %%
# Create and populate the Chroma vector store from document chunks
# Initialize Chroma vector store with the first batch
batch_size = 2000

vector_store = Chroma.from_documents(
    documents=doc_chunks[:batch_size],
    embedding=embedding_model,
    persist_directory="./chroma_db"
)

# Add remaining chunks in batches
for i in range(batch_size, len(doc_chunks), batch_size):
    batch = doc_chunks[i : i + batch_size]
    vector_store.add_documents(batch)
    print(f"Added batch {i // batch_size + 1} ({len(batch)} chunks)")

# Persist the vector database to disk
vector_store.persist()
print("Vector database successfully built and persisted!")
# Out:
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Added batch 2 (2000 chunks)
# Added batch 3 (2000 chunks)
# Added batch 4 (2000 chunks)
# Added batch 5 (2000 chunks)
# Added batch 6 (2000 chunks)
# Added batch 7 (2000 chunks)
# Added batch 8 (2000 chunks)
# Added batch 9 (2000 chunks)
# Added batch 10 (71 chunks)
# Vector database successfully built and persisted!
# /usr/local/lib/python3.12/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   warn_deprecated(

# %% [markdown]
# ### Retriever

# %%
# Create the retriever from the Chroma vector store
retriever = vector_store.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 3}
)

# %% [markdown]
# ### System and User Prompt Template

# %%
# System prompt to define the role and constraints of the assistant
qna_system_message = """You are a helpful and accurate medical AI assistant.
Your task is to answer the user's medical question strictly based on the provided context from the Merck Manual.
If the answer cannot be found in the context, state clearly that the provided context does not contain enough information to answer the question.
Do not invent or extrapolate information beyond what is directly stated in the context."""

# Template for formatting the context and question
qna_user_message_template = """Context:
{context}

Question:
{question}

Answer:"""

# %% [markdown]
# ### Response Function

# %%
def generate_rag_response(user_input,k=3,max_tokens=128,temperature=0,top_p=0.95,top_k=50):
    global qna_system_message,qna_user_message_template
    # Retrieve relevant document chunks
    relevant_document_chunks = retriever.invoke(user_input)
    context_list = [d.page_content for d in relevant_document_chunks]

    # Combine document chunks into a single context
    context_for_query = ". ".join(context_list)

    user_message = qna_user_message_template.replace('{context}', context_for_query)
    user_message = user_message.replace('{question}', user_input)

    prompt = qna_system_message + '\n' + user_message

    # Generate the response
    try:
        response = llm(
                  prompt=prompt,
                  max_tokens=max_tokens,
                  temperature=temperature,
                  top_p=top_p,
                  top_k=top_k
                  )

        # Extract and print the model's response
        response = response['choices'][0]['text'].strip()
    except Exception as e:
        response = f'Sorry, I encountered the following error: \n {e}'

    return response

# %% [markdown]
# ## Question Answering using RAG

# %% [markdown]
# ### Query 1: What is the protocol for managing sepsis in a critical care unit?

# %%
# Query 1 using RAG
query = "What is the protocol for managing sepsis in a critical care unit?"
answer = generate_rag_response(query, max_tokens=512)
print(answer)
# Out:
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# Llama.generate: prefix-match hit
# The context provides information on the high incidence of sepsis in critical care units and mentions that treatment includes aggressive fluid resuscitation, antibiotics, surgical excision or drainage of infected tissues, supportive care, and sometimes intensive control of blood glucose and administration of corticosteroids and activated protein C. The context does not specify a particular protocol for managing sepsis in a critical care unit beyond these general measures.

# %% [markdown]
# ### Query 2: What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?

# %%
# Query 2 using RAG
query = "What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?"
answer = generate_rag_response(query, max_tokens=512)
print(answer)
# Out:
# Llama.generate: prefix-match hit
# The common symptoms of appendicitis include epigastric or periumbilical pain followed by brief nausea, vomiting, and anorexia. After a few hours, the pain shifts to the right lower quadrant. Pain increases with cough and motion. Classic signs are right lower quadrant direct and rebound tenderness located at McBurney's point. Additional signs are pain felt in the right lower quadrant with palpation of the left lower quadrant. If an abscess or inflammatory mass has formed, the procedure may be limited to drainage of the abscess. Appendicitis cannot be cured via medicine alone; surgical removal is the standard treatment. In the US, acute appendicitis is the most common cause of acute abdominal pain requiring surgery. It most commonly occurs in the teens and 20s but may occur at any age. Other conditions affecting the appendix include carcinoids, cancer, villous adenomas, diverticula, Crohn's disease, and ulcerative colitis with pancolitis.

# %% [markdown]
# ### Query 3: What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?

# %%
# Query 3 using RAG
query = "What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?"
answer = generate_rag_response(query, max_tokens=512)
print(answer)
# Out:
# Llama.generate: prefix-match hit
# Based on the context provided from the Merck Manual, the possible causes of sudden patchy hair loss include alopecia areata, tinea capitis, trichotillomania, and scarring alopecias. The treatments for these conditions vary. For alopecia areata, options include topical corticosteroids, minoxidil, anthralin, immunotherapy (diphencyprone or squaric acid dibutylester), or psoralen plus ultraviolet A (PUVA). For tinea capitis, treatment involves topical or oral antifungals. Traction alopecia is treated by eliminating physical traction or stress to the scalp. Trichotillomania can be difficult to treat but behavior modification, clomipramine, or an SSRI (such as fluoxetine, fluvoxamine, paroxetine, sertraline, or citalopram) may be of benefit. It is important to note that the cause of the sudden patchy hair loss cannot be definitively determined without a proper diagnosis from a healthcare professional.

# %% [markdown]
# ### Query 4:  What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?

# %%
# Query 3 using RAG
query = "What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?"
answer = generate_rag_response(query, max_tokens=512)
print(answer)
# Out:
# Llama.generate: prefix-match hit
# Based on the context provided from the Merck Manual, the possible causes of sudden patchy hair loss include alopecia areata, tinea capitis, trichotillomania, and scarring alopecias. The treatments for these conditions vary. For alopecia areata, options include topical corticosteroids, minoxidil, anthralin, immunotherapy (diphencyprone or squaric acid dibutylester), or psoralen plus ultraviolet A (PUVA). For tinea capitis, treatment involves topical or oral antifungals. Traction alopecia is treated by eliminating physical traction or stress to the scalp. Trichotillomania can be difficult to treat but behavior modification, clomipramine, or an SSRI (such as fluoxetine, fluvoxamine, paroxetine, sertraline, or citalopram) may be of benefit. It is important to note that the cause of the sudden patchy hair loss cannot be definitively determined without a proper diagnosis from a healthcare professional.

# %% [markdown]
# ### Query 5: What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?

# %%
# Query 5 using RAG
query = "What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?"
answer = generate_rag_response(query, max_tokens=512)
print(answer)
# Out:
# Llama.generate: prefix-match hit
# Based on the context from the Merck Manual, for a person who has fractured their leg during a hiking trip, the following precautions and treatment steps are necessary:
# 1. Immediate immobilization of the affected limb by splinting to prevent further injury to soft tissues.
# 2. Treatment for life- or limb-threatening injuries such as hemorrhagic shock if present.
# 3. Surgical repair for arterial injuries, if they affect large arteries with poor collateral circulation.
# 4. Observation and supportive measures for nerve injuries such as neuropraxia and axonotmesis.
# 5. Rest, ice, compression, and elevation (RICE) of the affected limb.
# 6. Definitive treatment for certain injuries, such as reduction.
# 7. Keeping the wound clean and dry, applying nonadherent and impermeable to bacteria dressings, and using antibiotic ointment daily until the wound closure device is removed.
# ...

# %% [markdown]
# ### Fine-tuning

# %% [markdown]
# ### 🛠️ Final Clean Environment Setup
# Run this cell to perform a complete purge and clean install of compatible versions for the T4 GPU. This resolves the `ncclCommResume` and `torchvision::nms` errors.

# %%
# 1. Purge all conflicting packages and physical files
# !pip uninstall -y torch torchvision torchaudio xformers unsloth unsloth-zoo trl peft accelerate bitsandbytes
# !rm -rf /usr/local/lib/python3.12/dist-packages/torch*
# !rm -rf /usr/local/lib/python3.12/dist-packages/unsloth*

# 2. Install stable, verified compatible stack for Colab T4 (CUDA 12.1)
# !pip install --no-cache-dir -q "torch==2.3.1" "torchvision==0.18.1" "xformers==0.0.27" --index-url https://download.pytorch.org/whl/cu121

# 3. Install Unsloth and specific training dependencies
# !pip install --no-cache-dir -q "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-cache-dir -q --no-deps trl peft accelerate bitsandbytes

# 4. Success check
import torch
print(f"Target Torch 2.3.1 installed: {torch.__version__ == '2.3.1'}")

# 5. Force session exit to refresh environment
import os
os._exit(0)
# Out:
# Found existing installation: torch 2.12.1
# Uninstalling torch-2.12.1:
#   Successfully uninstalled torch-2.12.1
# Found existing installation: torchvision 0.18.1+cu121
# Uninstalling torchvision-0.18.1+cu121:
#   Successfully uninstalled torchvision-0.18.1+cu121
# WARNING: Skipping torchaudio as it is not installed.
# Found existing installation: xformers 0.0.27
# Uninstalling xformers-0.0.27:
#   Successfully uninstalled xformers-0.0.27
# Found existing installation: unsloth 2026.7.5
# Uninstalling unsloth-2026.7.5:
#   Successfully uninstalled unsloth-2026.7.5
# Found existing installation: unsloth_zoo 2026.7.6
# Uninstalling unsloth_zoo-2026.7.6:
#   Successfully uninstalled unsloth_zoo-2026.7.6
# Found existing installation: trl 0.24.0
# Uninstalling trl-0.24.0:
#   Successfully uninstalled trl-0.24.0
# Found existing installation: peft 0.19.1
# Uninstalling peft-0.19.1:
#   Successfully uninstalled peft-0.19.1
# Found existing installation: accelerate 1.14.0
# ...

# %% [markdown]
# ### 🛠️ Ultimate Fix for SFTTrainer Errors
# This cell uninstalls all conflicting versions and installs the precise stable stack required for the Mistral fine-tuning. **After running this, you MUST manually click 'Runtime' -> 'Restart session'.**

# %%
# 1. Deep clean and purge all previous attempts
# !pip uninstall -y torch torchvision torchaudio xformers unsloth unsloth-zoo trl peft accelerate bitsandbytes
# !rm -rf /usr/local/lib/python3.12/dist-packages/torch*

# 2. Install specific CUDA 12.1 compatible versions for Colab T4
# !pip install --no-cache-dir -q "torch==2.3.1" "torchvision==0.18.1" "xformers==0.0.27" --index-url https://download.pytorch.org/whl/cu121

# 3. Install Unsloth and specific dependencies
# !pip install --no-cache-dir -q "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-cache-dir -q --no-deps trl peft accelerate bitsandbytes

print("Installation complete. PLEASE RESTART SESSION MANUALLY NOW (Runtime > Restart session) and then run the training cell.")
# Out:
# Found existing installation: torch 2.12.1
# Uninstalling torch-2.12.1:
#   Successfully uninstalled torch-2.12.1
# Found existing installation: torchvision 0.18.1+cu121
# Uninstalling torchvision-0.18.1+cu121:
#   Successfully uninstalled torchvision-0.18.1+cu121
# WARNING: Skipping torchaudio as it is not installed.
# Found existing installation: xformers 0.0.27
# Uninstalling xformers-0.0.27:
#   Successfully uninstalled xformers-0.0.27
# Found existing installation: unsloth 2026.7.5
# Uninstalling unsloth-2026.7.5:
#   Successfully uninstalled unsloth-2026.7.5
# Found existing installation: unsloth_zoo 2026.7.6
# Uninstalling unsloth_zoo-2026.7.6:
#   Successfully uninstalled unsloth_zoo-2026.7.6
# Found existing installation: trl 0.24.0
# Uninstalling trl-0.24.0:
#   Successfully uninstalled trl-0.24.0
# Found existing installation: peft 0.19.1
# Uninstalling peft-0.19.1:
#   Successfully uninstalled peft-0.19.1
# Found existing installation: accelerate 1.14.0
# ...

# %%
import os
import shutil

# 1. Force remove torch directories to clear binary cache
paths_to_remove = [
    '/usr/local/lib/python3.12/dist-packages/torch',
    '/usr/local/lib/python3.12/dist-packages/torchvision',
    '/usr/local/lib/python3.12/dist-packages/xformers'
]

for path in paths_to_remove:
    if os.path.exists(path):
        print(f'Removing {path}...')
        shutil.rmtree(path)

# 2. Reinstall specific CUDA 12.1 compatible versions
# !pip install --no-cache-dir -q "torch==2.3.1" "torchvision==0.18.1" "xformers==0.0.27" --index-url https://download.pytorch.org/whl/cu121
# !pip install --no-cache-dir -q "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-cache-dir -q --no-deps trl peft accelerate bitsandbytes

print('\n' + '='*50)
print('DEEP PURGE COMPLETE.')
print('ACTION REQUIRED: Click "Runtime" -> "Restart session" in the top menu now.')
print('='*50)
# Out:
# Removing /usr/local/lib/python3.12/dist-packages/torch...
# Removing /usr/local/lib/python3.12/dist-packages/torchvision...
# Removing /usr/local/lib/python3.12/dist-packages/xformers...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.9/780.9 MB 368.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unsloth-zoo 2026.7.6 requires torch<2.13.0,>=2.4.0; sys_platform != "darwin" or platform_machine != "arm64", but you have torch 2.3.1+cu121 which is incompatible.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.3/532.3 MB 210.2 MB/s eta 0:00:00
# ...

# %%
import os
# 1. Manually prepend the Torch library path to bypass stale system links
os.environ['LD_LIBRARY_PATH'] = '/usr/local/lib/python3.12/dist-packages/torch/lib:' + os.environ.get('LD_LIBRARY_PATH', '')

# 2. Re-run ldconfig for the specific torch directory
# !ldconfig /usr/local/lib/python3.12/dist-packages/torch/lib

print(f'Updated LD_LIBRARY_PATH: {os.environ.get("LD_LIBRARY_PATH")}')
print('\nACTION REQUIRED: Click "Runtime" -> "Restart session" now!')
# Out:
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# ...

# %%
import torch
from unsloth import FastLanguageModel
from datasets import Dataset
from trl import SFTTrainer
from transformers import TrainingArguments

# 1. Load 4-bit quantized Mistral-7B (fits easily under Colab's 15GB T4 VRAM)
max_seq_length = 2048
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/mistral-7b-instruct-v0.2-bnb-4bit",
    max_seq_length=max_seq_length,
    dtype=None,
    load_in_4bit=True,
)

# 2. Add LoRA adapters
model = FastLanguageModel.get_peft_model(
    model,
    r=16,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    lora_alpha=16,
    lora_dropout=0,
    bias="none",
    use_gradient_checkpointing="unsloth",
)

# 3. Format Dataset
data = [
    {
        "instruction": "What is the protocol for managing sepsis in a critical care unit?",
        "output": "The protocol for managing sepsis includes immediate fluid resuscitation with isotonic crystalloids, early broad-spectrum antimicrobial therapy, source control, hemodynamic monitoring, and supportive care."
    },
    {
        "instruction": "What are the common symptoms for appendicitis?",
        "output": "Common symptoms include epigastric or periumbilical pain shifting to the right lower quadrant, brief nausea, vomiting, anorexia, and localized tenderness at McBurney's point."
    }
]

def format_prompts(batch):
    formatted = []
    for inst, out in zip(batch['instruction'], batch['output']):
        text = f"<s>[INST] {inst} [/INST] {out}</s>"
        formatted.append(text)
    return {"text": formatted}

dataset = Dataset.from_dict({
    "instruction": [item["instruction"] for item in data],
    "output": [item["output"] for item in data]
})
dataset = dataset.map(format_prompts, batched=True)

# 4. Train with SFTTrainer
trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    dataset_num_proc=2,
    packing=False,
    args=TrainingArguments(
        per_device_train_batch_size=2,
        gradient_accumulation_steps=4,
        warmup_steps=5,
        max_steps=60,
        learning_rate=2e-4,
        fp16=not torch.cuda.is_bf16_supported(),
        bf16=torch.cuda.is_bf16_supported(),
        logging_steps=1,
        optim="adamw_8bit",
        output_dir="outputs",
    ),
)

trainer.train()
print("LoRA Fine-Tuning completed successfully without crashing!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_26456/1433301416.py in <cell line: 0>()
# ----> 1 import torch
#       2 from unsloth import FastLanguageModel
#       3 from datasets import Dataset
#       4 from trl import SFTTrainer
#       5 from transformers import TrainingArguments
#
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py in <module>
#     442     if USE_GLOBAL_DEPS:
#     443         _load_global_deps()
# --> 444     from torch._C import *  # noqa: F403
#     445
#     446
#
# ImportError: /usr/local/lib/python3.12/dist-packages/torch/lib/libtorch_cuda.so: undefined symbol: ncclCommResume
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# ...

# %%
model_id = "mistralai/Mistral-7B-Instruct-v0.2"

# 4-bit quantization configuration to fit within Colab T4 GPU VRAM
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True
)

tokenizer = AutoTokenizer.from_pretrained(model_id)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    device_map="auto"
)

# Prepare model for PEFT/LoRA training
model = prepare_model_for_kbit_training(model)

peft_config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, peft_config)
model.print_trainable_parameters()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_26034/526159813.py in <cell line: 0>()
#       2
#       3 # 4-bit quantization configuration to fit within Colab T4 GPU VRAM
# ----> 4 bnb_config = BitsAndBytesConfig(
#       5     load_in_4bit=True,
#       6     bnb_4bit_quant_type="nf4",
#
# NameError: name 'BitsAndBytesConfig' is not defined

# %%
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,
    learning_rate=2e-4,
    logging_steps=10,
    max_steps=100,  # Adjust based on dataset size
    optim="paged_adamw_8bit",
    fp16=True,
    save_strategy="no"
)

trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=512,
    tokenizer=tokenizer,
    args=training_args,
)

trainer.train()

# Save the LoRA adapter weights
model.save_pretrained("./mistral_medical_lora")
tokenizer.save_pretrained("./mistral_medical_lora")
print("LoRA Fine-Tuning Complete!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29062/1696433776.py in <cell line: 0>()
# ----> 1 training_args = TrainingArguments(
#       2     output_dir="./results",
#       3     per_device_train_batch_size=2,
#       4     gradient_accumulation_steps=4,
#       5     learning_rate=2e-4,
#
# NameError: name 'TrainingArguments' is not defined

# %% [markdown]
# ## Output Evaluation

# %% [markdown]
# Let us now use the LLM-as-a-judge method to check the quality of the RAG system on two parameters - retrieval and generation. We illustrate this evaluation based on the answeres generated to the question from the previous section.
#
# - We are using the same Mistral model for evaluation, so basically here the llm is rating itself on how well he has performed in the task.

# %%
groundedness_rater_system_message  = ""

# %%
relevance_rater_system_message = ""

# %%
user_message_template = ""

# %%
def generate_ground_relevance_response(user_input,k=3,max_tokens=128,temperature=0,top_p=0.95,top_k=50):
    global qna_system_message,qna_user_message_template
    # Retrieve relevant document chunks
    relevant_document_chunks = retriever.get_relevant_documents(query=user_input,k=3)
    context_list = [d.page_content for d in relevant_document_chunks]
    context_for_query = ". ".join(context_list)

    # Combine user_prompt and system_message to create the prompt
    prompt = f"""[INST]{qna_system_message}\n
                {'user'}: {qna_user_message_template.format(context=context_for_query, question=user_input)}
                [/INST]"""

    response = llm(
            prompt=prompt,
            max_tokens=max_tokens,
            temperature=temperature,
            top_p=top_p,
            top_k=top_k,
            stop=['INST'],
            )

    answer =  response["choices"][0]["text"]

    # Combine user_prompt and system_message to create the prompt
    groundedness_prompt = f"""[INST]{groundedness_rater_system_message}\n
                {'user'}: {user_message_template.format(context=context_for_query, question=user_input, answer=answer)}
                [/INST]"""

    # Combine user_prompt and system_message to create the prompt
    relevance_prompt = f"""[INST]{relevance_rater_system_message}\n
                {'user'}: {user_message_template.format(context=context_for_query, question=user_input, answer=answer)}
                [/INST]"""

    response_1 = llm(
            prompt=groundedness_prompt,
            max_tokens=max_tokens,
            temperature=temperature,
            top_p=top_p,
            top_k=top_k,
            stop=['INST'],
            )

    response_2 = llm(
            prompt=relevance_prompt,
            max_tokens=max_tokens,
            temperature=temperature,
            top_p=top_p,
            top_k=top_k,
            stop=['INST'],
            )

    return response_1['choices'][0]['text'],response_2['choices'][0]['text']

# %% [markdown]
# ### Query 1: What is the protocol for managing sepsis in a critical care unit?

# %% [markdown]
# ### Query 2: What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?

# %% [markdown]
# ### Query 3: What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?

# %% [markdown]
# ### Query 4: What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?

# %% [markdown]
# ### Query 5: What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?

# %% [markdown]
# ## Actionable Insights and Business Recommendations

# %% [markdown]
# <font size=6 color='blue'>Power Ahead</font>
# ___
